# %% [markdown]
# # Pandas Exercise: Visualization (Online Retails Purchase)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Visualization/Online_Retail/Online_Retail.csv).

# %%
pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise8 files\\Online_Retail.csv',encoding='latin1')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5         536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6         536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 8         536366     22632            HAND WARMER RED POLKA DOT         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 10        536367     22745           POPPY'S PLAYHOUSE BEDROOM          6
# 11        536367     22748            POPPY'S PLAYHOUSE KITCHEN         6
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable called online_rt

# %%
online_rt =pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise8 files\\Online_Retail.csv',encoding='latin1')

# %% [markdown]
# ### Step 4. Create a histogram with the 10 countries that have the most 'Quantity' ordered except UK

# %%
online_rt.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
online_rt[online_rt['Country'] != 'United Kingdom'][['Country','Quantity']].groupby('Country').sum().sort_values(by= 'Quantity', ascending = False).head(10).plot(kind = 'hist')

# %% [markdown]
# ### Step 5.  Exclude negative Quatity entries

# %%
online_rt = online_rt[online_rt['Quantity'] > 0]

# %% [markdown]
# ### Step 6. Create a scatterplot with the Quantity per UnitPrice by CustomerID for the top 3 Countries

# %%
online_rt[['Country','Quantity']].groupby('Country').sum().sort_values(by = 'Quantity', ascending = False).head(3)
# Out:
#                 Quantity
# Country
# United Kingdom   4733819
# Netherlands       200937
# EIRE              147447

# %%
Quantity = online_rt.Quantity[(online_rt['Country'] == 'United Kingdom') | (online_rt.Country == 'Netherlands') | (online_rt.Country == 'EIRE')]
Unitprice = online_rt.UnitPrice[(online_rt['Country'] == 'United Kingdom') | (online_rt.Country == 'Netherlands') | (online_rt.Country == 'EIRE')]

# %%
plt.scatter(Quantity,Unitprice)

# %% [markdown]
# ### BONUS: Create your own question and answer it.
