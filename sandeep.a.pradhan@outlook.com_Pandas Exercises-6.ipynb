# %% [markdown]
# # Pandas Exercise: Merging (MPG Cars)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the first dataset [cars1](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars1.csv) and [cars2](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/Merge/Auto_MPG/cars2.csv).

# %%
pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise6 files\\cars1.csv')
pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise6 files\\cars2.csv')
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    33.0          4            91         53    1795          17.4     76
# 1    20.0          6           225        100    3651          17.7     76
# 2    18.0          6           250         78    3574          21.0     76
# 3    18.5          6           250        110    3645          16.2     76
# 4    17.5          6           258         95    3193          17.8     76
# 5    29.5          4            97         71    1825          12.2     76
# 6    32.0          4            85         70    1990          17.0     76
# 7    28.0          4            97         75    2155          16.4     76
# 8    26.5          4           140         72    2565          13.6     76
# 9    20.0          4           130        102    3150          15.7     76
# 10   13.0          8           318        150    3940          13.2     76
# ...

# %% [markdown]
#    ### Step 3. Assign each to a to a variable called cars1 and cars2

# %%
cars1 = pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise6 files\\cars1.csv')
cars2 = pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\2. Pandas Basic Exercises\\Pandas Exercise6 files\\cars2.csv')

# %% [markdown]
# ### Step 4. Ops it seems our first dataset has some unnamed blank columns, fix cars1

# %%
cars1.rename(columns = {'Unnamed: 9':'x','Unnamed: 9':'x','Unnamed: 10':'y','Unnamed: 11':'z','Unnamed: 12':'x1','Unnamed: 13':'y1',}).head(3)
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  18.0          8           307        130    3504          12.0     70
# 1  15.0          8           350        165    3693          11.5     70
# 2  18.0          8           318        150    3436          11.0     70
#
#    origin                        car   x   y   z  x1  y1
# 0       1  chevrolet chevelle malibu NaN NaN NaN NaN NaN
# 1       1          buick skylark 320 NaN NaN NaN NaN NaN
# 2       1         plymouth satellite NaN NaN NaN NaN NaN

# %% [markdown]
# ### Step 5. What is the number of observations in each dataset?

# %%
print (cars1.size)
print (cars2.size)
# Out:
# 2772
# 1800

# %% [markdown]
# ### Step 6. Join cars1 and cars2 into a single DataFrame called cars

# %%
cars = pd.merge(cars1,cars2, on = 'model')

# %% [markdown]
# ### Step 7. Ops there is a column missing, called owners. Create a random number Series from 15,000 to 73,000.

# %%
np.random.randint(low = 1500,high = 73001, size = cars.size)
# Out:
# array([67344, 71037, 66751, ..., 18079, 44324, 14811])

# %% [markdown]
# ### Step 8. Add the column owners to cars

# %%
cars['owners'] = pd.DataFrame(np.random.randint(low = 1500,high = 73001, size = cars.size))
