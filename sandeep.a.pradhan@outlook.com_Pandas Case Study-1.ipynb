# %%
# 1. Import the customer data into python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
customer = pd.read_csv('C:\\Users\\sandeep.a.pradhan\\Documents\\ALabs\\Chandra\\Class 4-5\\3. Pandas Case Study-1\\Customers.csv', encoding = 'latin1')

# %%
#2. Understand the data using different functions and attributes like shape, index, columns, dtypes.ndim, info(), 
#get_dtype_counts etc.

# %%
customer.shape
# Out:
# (10000, 14)

# %%
customer.columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# Customer_ID        10000 non-null int64
# Gender             9986 non-null object
# First_Date         10000 non-null int64
# First_region       9979 non-null object
# First_state        9983 non-null object
# First_city         10000 non-null object
# Recent_Date        10000 non-null int64
# Last_region        10000 non-null object
# Last_state         10000 non-null object
# Last_city          10000 non-null object
# Customer_Value     9964 non-null float64
# Buy_Times          10000 non-null int64
# Points_Earned      9979 non-null float64
# Points_Redeemed    9988 non-null float64
# dtypes: float64(3), int64(4), object(7)
# memory usage: 1.1+ MB

# %%
customer.index
# Out:
# RangeIndex(start=0, stop=10000, step=1)

# %%
customer.ndim
# Out:
# 2

# %%
customer.get_dtype_counts()
# Out:
# float64    3
# int64      4
# object     7
# dtype: int64

# %%
#3. What is percentage of missing values for customer Value variable?

# %%
sum(customer['Customer_Value'].isnull())/customer['Customer_Value'].count()*100
# Out:
# 0.3613006824568446

# %%
#4. Create two subsets with unique and duplicate values.

# %%
# Duplicated Record
customer[customer.duplicated() == True].head()
# Out:
#       Customer_ID Gender  First_Date First_region  First_state First_city  \
# 9973     88092811      M    20120116         West      Gujarat      Surat
# 9974     84750517      F    20120119         West      Gujarat      Surat
# 9975      5686217      M    20120118         West  Maharashtra      Thane
# 9976     63669926      M    20120118        South    Telangana  Hyderabad
# 9977     90964885      M    20120121         West      Gujarat      Surat
#
#       Recent_Date Last_region Last_state  Last_city  Customer_Value  \
# 9973     20130222        West    Gujarat      Surat       14786.600
# 9974     20130319        West    Gujarat      Surat       20696.900
# 9975     20120524        West    Gujarat      Surat       16858.099
# 9976     20130114       South  Telangana  Hyderabad       12863.000
# 9977     20120121        West    Gujarat      Surat         198.000
#
#       Buy_Times  Points_Earned  Points_Redeemed
# 9973         12          337.0            300.0
# 9974         11         1935.0              0.0
# 9975         11          915.0              0.0
# 9976          4         1030.0              0.0
# 9977          1            0.0              0.0

# %%
# Duplicated Record
customer[customer.duplicated() == False].head()
# Out:
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed
# 0          2          200.0              0.0
# 1          1          100.0              0.0
# 2          1           10.0              0.0
# 3          1          170.0              0.0
# 4          1           60.0              0.0

# %%
#5. Create data set with list of customers whose customer value greater than 10000.

# %%
customer[customer['Customer_Value'] > 10000]
# Out:
#       Customer_ID Gender  First_Date First_region     First_state  \
# 14        1610085      F    20120103        North           Delhi
# 15        7518872      M    20120104        North   Uttar Pradesh
# 18       63508964      M    20120106         West     Maharashtra
# 19       23667984      F    20120107         West     Maharashtra
# 20       84634600      M    20120108        South       Karnataka
# 21       85207999      M    20120110        South  Andhra Pradesh
# 24       87030390      M    20120111         East     West Bengal
# 26       12935950      M    20120113         West         Gujarat
# 27       10954886      F    20120115        North  Madhya Pradesh
# 29        7514232      M    20120114        North           Delhi
# 30         328670      M    20120115        North           Delhi
# 31         237645      M    20120117        North  Madhya Pradesh
# 32       36292837      M    20120118         West         Gujarat
# 35       73792250      M    20120128         West         Gujarat
# 37       73957360      M    20120129         West         Gujarat
# 38        8068420      F    20120131        North   Uttar Pradesh
# 39        3021033      M    20120131        South       Karnataka
# 40        5912830      F    20120202         East     West Bengal
# 42        9046409      M    20120206         West     Maharashtra
# 43          93630      M    20120208         West         Gujarat
# 44       85323066      F    20120208         West     Maharashtra
# 45         303753      M    20120208        North  Madhya Pradesh
# 46       49886011      F    20120208         West     Maharashtra
# 50       85613515      M    20120213         West         Gujarat
# 53       55802349      F    20120224         West         Gujarat
# 54       84874275      M    20120224         West     Maharashtra
# 55        6898330      F    20120227         West         Gujarat
# 57      113932157      F    20120302         West         Gujarat
# 58        1747708      F    20120303        South       Karnataka
# 59        2780625      M    20120303         West         Gujarat
# ...           ...    ...         ...          ...             ...
# 9938      5686217      M    20120118         West     Maharashtra
# 9939     63669926      M    20120118        South       Telangana
# 9942      6005239      M    20120129         East     West Bengal
# 9943     91066310      M    20120130         West         Gujarat
# 9945      9144258      M    20120130        South      Tamil Nadu
# 9946     91076263      F    20120130         East     West Bengal
# 9947     85012902      M    20120201         West         Gujarat
# 9948     14762484      M    20120131        North  Madhya Pradesh
# 9958     50093138      M    20120208        North   Uttar Pradesh
# 9959     92763145      M    20120209        South       Telangana
# 9960     73839417      M    20120210        South       Karnataka
# 9964     74054076      F    20120110        North   Uttar Pradesh
# 9966     63594593      M    20120112         East     West Bengal
# 9967     87998623      M    20120112         East     West Bengal
# 9969     88068705      M    20120116         West         Gujarat
# 9970      5599557      F    20120115         West         Gujarat
# 9971      7956527      F    20120115        North           Delhi
# 9973     88092811      M    20120116         West         Gujarat
# 9974     84750517      F    20120119         West         Gujarat
# 9975      5686217      M    20120118         West     Maharashtra
# 9976     63669926      M    20120118        South       Telangana
# 9979      6005239      M    20120129         East     West Bengal
# 9980     91066310      M    20120130         West         Gujarat
# 9982      9144258      M    20120130        South      Tamil Nadu
# 9983     91076263      F    20120130         East     West Bengal
# 9984     85012902      M    20120201         West         Gujarat
# 9985     14762484      M    20120131        North  Madhya Pradesh
# 9995     50093138      M    20120208        North   Uttar Pradesh
# 9996     92763145      M    20120209        South       Telangana
# 9997     73839417      M    20120210        South       Karnataka
#
#             First_city  Recent_Date Last_region      Last_state  \
# 14               Delhi     20121013       North           Delhi
# 15              Kanpur     20130123       North   Uttar Pradesh
# 18    Pimpri-Chinchwad     20130222        West     Maharashtra
# 19              Nagpur     20130313        West     Maharashtra
# 20           Bangalore     20130307       South       Karnataka
# 21       Visakhapatnam     20121229       South  Andhra Pradesh
# 24             Kolkata     20130302        East     West Bengal
# 26               Surat     20120623        West         Gujarat
# 27              Indore     20130118       North  Madhya Pradesh
# 29               Delhi     20130108       North           Delhi
# 30               Delhi     20130302       North           Delhi
# 31              Indore     20130318       North  Madhya Pradesh
# 32               Surat     20130313        West         Gujarat
# 35               Surat     20130305        West         Gujarat
# 37               Surat     20130306        West         Gujarat
# 38              Kanpur     20130224       South      Tamil Nadu
# 39           Bangalore     20130218       South       Karnataka
# 40        South Dumdum     20130318        East       Jharkhand
# 42              Mumbai     20130327        West     Maharashtra
# 43               Surat     20130202        West         Gujarat
# 44              Mumbai     20130202        West     Maharashtra
# 45              Indore     20130321       North  Madhya Pradesh
# 46              Mumbai     20120518       South       Karnataka
# 50               Surat     20130312        West         Gujarat
# 53           Ahmedabad     20130225        West         Gujarat
# 54    Pimpri-Chinchwad     20130322        West     Maharashtra
# 55               Surat     20130308        West         Gujarat
# 57               Surat     20130201        West         Gujarat
# 58           Bangalore     20130324       North  Madhya Pradesh
# 59               Surat     20130124        West         Gujarat
# ...                ...          ...         ...             ...
# 9938             Thane     20120524        West         Gujarat
# 9939         Hyderabad     20130114       South       Telangana
# 9942           Kolkata     20121127       South       Telangana
# 9943             Surat     20130312        West         Gujarat
# 9945           Chennai     20130313        West     Maharashtra
# 9946           Kolkata     20130310        East     West Bengal
# 9947             Surat     20130310        West         Gujarat
# 9948            Indore     20121211       North  Madhya Pradesh
# 9958              Agra     20121114       North   Uttar Pradesh
# 9959         Hyderabad     20130319       South       Telangana
# 9960         Bangalore     20130216       South       Karnataka
# 9964            Kanpur     20121117       North   Uttar Pradesh
# 9966          Siliguri     20130204        East     West Bengal
# 9967          Durgapur     20130228       North   Uttar Pradesh
# 9969             Surat     20120704        West         Gujarat
# 9970            Rajkot     20130330        West         Gujarat
# 9971             Delhi     20130222       North           Delhi
# 9973             Surat     20130222        West         Gujarat
# 9974             Surat     20130319        West         Gujarat
# 9975             Thane     20120524        West         Gujarat
# 9976         Hyderabad     20130114       South       Telangana
# 9979           Kolkata     20121127       South       Telangana
# 9980             Surat     20130312        West         Gujarat
# 9982           Chennai     20130313        West     Maharashtra
# 9983           Kolkata     20130310        East     West Bengal
# 9984             Surat     20130310        West         Gujarat
# 9985            Indore     20121211       North  Madhya Pradesh
# 9995              Agra     20121114       North   Uttar Pradesh
# 9996         Hyderabad     20130319       South       Telangana
# 9997         Bangalore     20130216       South       Karnataka
#
#              Last_city  Customer_Value  Buy_Times  Points_Earned  \
# 14               Delhi     10380.19900          6         1189.0
# 15              Kanpur     14587.00000          6          865.0
# 18    Pimpri-Chinchwad    145472.70200         36          680.0
# 19              Nagpur     19640.70000         12          268.0
# 20           Bangalore     32377.60200         22         1029.0
# 21       Visakhapatnam     17202.40000         13          449.0
# 24             Kolkata     33047.00400         31          141.0
# 26           Ahmedabad     18358.00000          6          874.0
# 27              Indore     15426.39800         13         1672.0
# 29               Delhi     51692.99900         29         4275.0
# 30               Delhi     10547.79600         11          574.0
# 31              Indore    173171.70000         34        12737.0
# 32               Surat     18412.20000         19          158.0
# 35               Surat     29460.00000          6         2440.0
# 37               Surat     28291.29800         29          225.0
# 38             Chennai     11316.00100          6          684.0
# 39           Bangalore     48674.40100          6          244.0
# 40             Dhanbad     15478.00000          9         1895.0
# 42              Mumbai     20520.80000         13          641.0
# 43               Surat     11148.00000          7          960.0
# 44              Mumbai     41852.79800         16         1453.0
# 45              Indore     54342.00000         32         2061.0
# 46           Bangalore     15092.80000          5         1381.0
# 50               Surat     37192.00100         13         1837.0
# 53           Ahmedabad     15695.50000          9          983.0
# 54    Pimpri-Chinchwad    107078.39900         37         4083.0
# 55               Surat     20211.90000         17         1205.0
# 57               Surat     32085.69800         16          537.0
# 58              Indore     18881.78574         14          588.0
# 59               Surat     16471.90100          9          555.0
# ...                ...             ...        ...            ...
# 9938             Surat     16858.09900         11          915.0
# 9939         Hyderabad     12863.00000          4         1030.0
# 9942         Hyderabad     12246.80000          6          600.0
# 9943             Surat     11723.00000         10          475.0
# 9945            Mumbai     42195.09900         23         4441.0
# 9946           Kolkata     34492.90100         14         1591.0
# 9947             Surat     30123.30000          9         1555.0
# 9948            Bhopal     88407.50000         23         4317.0
# 9958              Agra     13818.60000          7         1195.0
# 9959         Hyderabad     13016.50000          7          870.0
# 9960         Bangalore     44057.90000         11         2242.0
# 9964            Kanpur     13485.10100         10          166.0
# 9966          Siliguri     10379.00000          4          495.0
# 9967            Kanpur     24378.00000          9         1506.0
# 9969             Surat     10996.00000          3          680.0
# 9970            Rajkot     74662.77636         36           22.0
# 9971             Delhi     66082.19900         37         2385.0
# 9973             Surat     14786.60000         12          337.0
# 9974             Surat     20696.90000         11         1935.0
# 9975             Surat     16858.09900         11          915.0
# 9976         Hyderabad     12863.00000          4         1030.0
# 9979         Hyderabad     12246.80000          6          600.0
# 9980             Surat     11723.00000         10          475.0
# 9982            Mumbai     42195.09900         23         4441.0
# 9983           Kolkata     34492.90100         14         1591.0
# 9984             Surat     30123.30000          9         1555.0
# 9985            Bhopal     88407.50000         23         4317.0
# 9995              Agra     13818.60000          7         1195.0
# 9996         Hyderabad     13016.50000          7          870.0
# 9997         Bangalore     44057.90000         11         2242.0
#
#       Points_Redeemed
# 14                0.0
# 15                0.0
# 18            16635.0
# 19             2549.0
# 20             1771.0
# 21                0.0
# 24             2214.0
# 26                0.0
# 27                0.0
# 29               12.0
# 30             2120.0
# 31                0.0
# 32             1260.0
# 35                0.0
# 37             1886.0
# 38              267.0
# 39             2270.0
# 40                0.0
# 42              780.0
# 43                0.0
# 44              415.0
# 45             9320.0
# 46                0.0
# 50              540.0
# 53                0.0
# 54                0.0
# 55                0.0
# 57             2401.0
# 58             2481.0
# 59                0.0
# ...               ...
# 9938              0.0
# 9939              0.0
# 9942              0.0
# 9943              0.0
# 9945              0.0
# 9946              0.0
# 9947              0.0
# 9948              0.0
# 9958           1800.0
# 9959              0.0
# 9960            585.0
# 9964            810.0
# 9966              0.0
# 9967              0.0
# 9969              0.0
# 9970          10472.0
# 9971          13520.0
# 9973            300.0
# 9974              0.0
# 9975              0.0
# 9976              0.0
# 9979              0.0
# 9980              0.0
# 9982              0.0
# 9983              0.0
# 9984              0.0
# 9985              0.0
# 9995           1800.0
# 9996              0.0
# 9997            585.0
#
# [2723 rows x 14 columns]

# %%
#6. In customer table, create a new variable called “customer value segment” using customer value as follows. -  
#- High Value Segment - > 25000  
#- Medium Value Segment – Between 10000 and 25000  
#- Low Value Segment – less than or equal to 10000

# %%
Customer_Value_segment = []
for i in customer['Customer_Value']:
    if i <= 10000:
        Customer_Value_segment.append('Low Value Segment')
        print ('Low Value Segment')
    elif i > 10000 and i < 25000:
        Customer_Value_segment.append('Medium Value segment')
        print ('Medium Value segment')
    else:
        Customer_Value_segment.append('High Value Segment')
        print ('High Value Segment')
customer['Customer Value Segment'] = pd.DataFrame(Customer_Value_segment)
# Out:
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# ...
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Medium Value segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# Low Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# High Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Low Value Segment
# Medium Value segment
# Medium Value segment
# High Value Segment
# Low Value Segment
# Low Value Segment
#    Customer_ID Gender  First_Date First_region  First_state        First_city  \
# 0    129609144      M    20130130         West      Gujarat             Surat
# 1    129627580      M    20130129        North        Delhi             Delhi
# 2    130363481      M    20130221         West      Gujarat             Surat
# 3     49817480      M    20130222         West  Maharashtra  Pimpri-Chinchwad
# 4    126343829      F    20130301        North        Delhi             Delhi
#
#    Recent_Date Last_region   Last_state         Last_city  Customer_Value  \
# 0     20130216        West      Gujarat             Surat          2032.0
# 1     20130129       North        Delhi             Delhi          1709.0
# 2     20130221        West      Gujarat             Surat           523.0
# 3     20130222        West  Maharashtra  Pimpri-Chinchwad          5132.0
# 4     20130301       North        Delhi             Delhi          1008.0
#
#    Buy_Times  Points_Earned  Points_Redeemed Customer Value Segment
# 0          2          200.0              0.0      Low Value Segment
# 1          1          100.0              0.0      Low Value Segment
# 2          1           10.0              0.0      Low Value Segment
# 3          1          170.0              0.0      Low Value Segment
# 4          1           60.0              0.0      Low Value Segment

# %%
customer.tail()
# Out:
#       Customer_ID Gender  First_Date First_region    First_state First_city  \
# 9995     50093138      M    20120208        North  Uttar Pradesh       Agra
# 9996     92763145      M    20120209        South      Telangana  Hyderabad
# 9997     73839417      M    20120210        South      Karnataka  Bangalore
# 9998     69606859      M    20120215        North  Uttar Pradesh    Lucknow
# 9999    113292109      M    20120217         West    Maharashtra     Mumbai
#
#       Recent_Date Last_region     Last_state  Last_city  Customer_Value  \
# 9995     20121114       North  Uttar Pradesh       Agra         13818.6
# 9996     20130319       South      Telangana  Hyderabad         13016.5
# 9997     20130216       South      Karnataka  Bangalore         44057.9
# 9998     20120215       North  Uttar Pradesh    Lucknow          1116.0
# 9999     20120217        West    Maharashtra     Mumbai          1222.0
#
#       Buy_Times  Points_Earned  Points_Redeemed Customer Value Segment
# 9995          7         1195.0           1800.0   Medium Value segment
# 9996          7          870.0              0.0   Medium Value segment
# 9997         11         2242.0            585.0     High Value Segment
# 9998          1            0.0            310.0      Low Value Segment
# 9999          1           60.0              0.0      Low Value Segment

# %%
#7. Create variables “average revenue per trip” and “balance points” in the customer data set.

# %%
customer.head(3)
# Out:
#    Customer_ID Gender  First_Date First_region First_state First_city  \
# 0    129609144      M    20130130         West     Gujarat      Surat
# 1    129627580      M    20130129        North       Delhi      Delhi
# 2    130363481      M    20130221         West     Gujarat      Surat
#
#    Recent_Date Last_region Last_state Last_city  Customer_Value  Buy_Times  \
# 0     20130216        West    Gujarat     Surat          2032.0          2
# 1     20130129       North      Delhi     Delhi          1709.0          1
# 2     20130221        West    Gujarat     Surat           523.0          1
#
#    Points_Earned  Points_Redeemed Customer Value Segment
# 0          200.0              0.0      Low Value Segment
# 1          100.0              0.0      Low Value Segment
# 2           10.0              0.0      Low Value Segment

# %%
#8. How many days between last purchase date and today?

# %%
#9. Calculate percentage of sales by each last city, state and region.

# %%
customer[['Last_city','Buy_Times']].groupby('Last_city').sum()
# Out:
#                     Buy_Times
# Last_city
# Agartala                   16
# Agra                      160
# Ahmedabad                3516
# Aligarh                    36
# Allahabad                   7
# Ambattur                   54
# Ambernath                   5
# Asansol                     3
# Aurangabad                 43
# Bangalore                3204
# Baranagar                   7
# Barasat                     2
# Bareilly                   12
# Begusarai                   9
# Bhagalpur                   3
# Bharatpur                   8
# Bhatpara                   42
# Bhilwara                   31
# Bhiwandi                    3
# Bhopal                   1530
# Bhubaneswar                29
# Bikaner                    16
# Chandigarh                 24
# Chennai                  2661
# Cuttack                    52
# Davanagere                  5
# Dehradun                    2
# Delhi                    5257
# Dewas                       3
# Dhanbad                    86
# ...                       ...
# Raichur                     6
# Raipur                      3
# Rajkot                   2041
# Rajpur Sonarpur             4
# Rampur                      4
# Ranchi                     37
# Rewa                        2
# Saharanpur                 19
# Salem                      22
# Satna                       9
# Sikar                       5
# Siliguri                    4
# Sonipat                    13
# Sri Ganganagar             14
# Srinagar                    4
# Surat                   11525
# Thane                     154
# Thiruvananthapuram         12
# Thoothukudi                 9
# Thrissur                    4
# Tirunelveli                 5
# Tirupati                   12
# Tiruvottiyur                6
# Ulhasnagar                  5
# Vadodara                 1720
# Vasai-Virar                81
# Vijayawada                202
# Visakhapatnam             546
# Vizianagaram               12
# Warangal                    7
#
# [116 rows x 1 columns]

# %%
#10. What is the count of customers, average number of purchases and average purchase transaction value by last state 
#and city.

# %%
customer.columns
# Out:
# Index(['Customer_ID', 'Gender', 'First_Date', 'First_region', 'First_state',
#        'First_city', 'Recent_Date', 'Last_region', 'Last_state', 'Last_city',
#        'Customer_Value', 'Buy_Times', 'Points_Earned', 'Points_Redeemed'],
#       dtype='object')

# %% [raw]
# Average_Number_Purchases = Buy_Times
# Average_purchase_Transaction = Customer_value
# Customer_Count = Customer_ID

# %%
#Customer_Count
Customer_Count = customer['Customer_ID'].groupby([customer.Last_state,customer.Last_city]).count()

# %%
#Average_Number_Purchases
Average_Number_Purchases = customer['Buy_Times'].groupby([customer.Last_state,customer.Last_city]).mean()

# %%
#Average_purchase_Transaction
Average_purchase_Transaction = customer['Customer_Value'].groupby([customer.Last_state,customer.Last_city]).mean()

# %%
pd.DataFrame(pd.concat([Customer_Count,Average_Number_Purchases,Average_purchase_Transaction],axis = 1).values,columns = ['Customer_Count','Average_Number_Purchases','Average_purchase_Transaction'])
# Out:
#      Customer_Count  Average_Number_Purchases  Average_purchase_Transaction
# 0               1.0                  3.000000                      0.000000
# 1               1.0                  4.000000                   3113.499000
# 2               2.0                  6.000000                   9250.000000
# 3              20.0                 10.100000                  24670.100100
# 4             117.0                  4.666667                  11135.137740
# 5               1.0                 12.000000                  23042.600000
# 6              30.0                 27.766667                  64887.960200
# 7               1.0                  9.000000                  25697.999000
# 8               1.0                  3.000000                   2787.799000
# 9               2.0                 11.500000                  29301.149500
# 10             20.0                  6.000000                  11568.565050
# 11              1.0                  4.000000                   7334.000000
# 12              6.0                  4.000000                   6826.633167
# 13              1.0                  3.000000                   2786.400000
# 14              1.0                  3.000000                   3866.000000
# 15           1034.0                  5.084139                  10444.385080
# 16              2.0                  4.000000                   4893.300000
# 17              1.0                  3.000000                   2660.000000
# 18            621.0                  5.661836                  12283.865858
# 19              1.0                  2.000000                   2089.000000
# 20              6.0                 10.166667                  14757.433500
# 21            235.0                  8.685106                  19370.660067
# 22           2127.0                  5.418430                  14611.418879
# 23            388.0                  4.432990                   9643.594421
# 24              1.0                 63.000000                 157822.500000
# 25              1.0                  2.000000                   2672.000000
# 26              1.0                 13.000000                  16375.000000
# 27              1.0                  4.000000                   6099.000000
# 28             18.0                  4.777778                  13711.677833
# 29              1.0                  2.000000                   3559.999000
# ..              ...                       ...                           ...
# 86              9.0                  4.000000                   3541.444444
# 87              2.0                  3.500000                   2791.950000
# 88              3.0                  4.000000                  11728.333333
# 89              1.0                  9.000000                  10812.000000
# 90              4.0                  6.750000                  15407.675000
# 91             27.0                  6.592593                  10905.888423
# 92              4.0                  2.750000                   5668.699750
# 93            854.0                  4.956674                  11181.490803
# 94             10.0                  4.500000                   5172.279900
# 95            219.0                  3.785388                  10548.547255
# 96              6.0                  8.166667                  16631.481073
# 97              1.0                  4.000000                   7174.200000
# 98              7.0                  4.428571                   5770.800143
# 99              1.0                  3.000000                   4881.000000
# 100             2.0                  4.500000                   5578.600000
# 101             1.0                  6.000000                   8228.600000
# 102             1.0                  4.000000                   9923.797000
# 103             2.0                  9.500000                  28426.250000
# 104             1.0                  2.000000                   1535.001000
# 105             1.0                  6.000000                  28271.600000
# 106             1.0                  3.000000                   3794.000000
# 107             2.0                  3.500000                   9970.950000
# 108             1.0                  2.000000                   5034.895040
# 109             4.0                 10.500000                  19856.000000
# 110             3.0                  4.333333                   7417.633333
# 111           543.0                  6.046041                  12853.575301
# 112             3.0                  3.333333                   9514.733333
# 113             1.0                  7.000000                   6923.003000
# 114             2.0                  2.000000                   1083.000000
# 115             1.0                  4.000000                  10379.000000
#
# [116 rows x 3 columns]
